# %%
import pandas as pd

# %%
df = pd.read_csv("../data/Palo Alto Networks.csv")

# %%
df.head()
# Out:
#    Age  Attrition     BusinessTravel  DailyRate              Department  \
# 0   41          1      Travel_Rarely       1102                   Sales
# 1   49          0  Travel_Frequently        279  Research & Development
# 2   37          1      Travel_Rarely       1373  Research & Development
# 3   33          0  Travel_Frequently       1392  Research & Development
# 4   27          0      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EnvironmentSatisfaction  \
# 0                 1          2  Life Sciences                        2
# 1                 8          1  Life Sciences                        3
# 2                 2          2          Other                        4
# 3                 3          4  Life Sciences                        4
# 4                 2          1        Medical                        1
#
#    Gender  ...  PerformanceRating  RelationshipSatisfaction  StockOptionLevel  \
# ...

# %%
df.shape
df.columns
df.info()
df.isnull().sum()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 31 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   int64
#  1   Attrition                 1470 non-null   int64
#  2   BusinessTravel            1470 non-null   object
#  3   DailyRate                 1470 non-null   int64
#  4   Department                1470 non-null   object
#  5   DistanceFromHome          1470 non-null   int64
#  6   Education                 1470 non-null   int64
#  7   EducationField            1470 non-null   object
#  8   EnvironmentSatisfaction   1470 non-null   int64
#  9   Gender                    1470 non-null   object
#  10  HourlyRate                1470 non-null   int64
#  11  JobInvolvement            1470 non-null   int64
#  12  JobLevel                  1470 non-null   int64
#  13  JobRole                   1470 non-null   object
# ...

# %%
categorical_columns = df.select_dtypes(include="object").columns

for column in categorical_columns:
    print(f"\n{column}:")
    print(df[column].unique())
# Out:
# BusinessTravel:
# ['Travel_Rarely' 'Travel_Frequently' 'Non-Travel']
#
# Department:
# ['Sales' 'Research & Development' 'Human Resources']
#
# EducationField:
# ['Life Sciences' 'Other' 'Medical' 'Marketing' 'Technical Degree'
#  'Human Resources']
#
# Gender:
# ['Female' 'Male']
#
# JobRole:
# ['Sales Executive' 'Research Scientist' 'Laboratory Technician'
#  'Manufacturing Director' 'Healthcare Representative' 'Manager'
#  'Sales Representative' 'Research Director' 'Human Resources']
#
# MaritalStatus:
# ['Single' 'Married' 'Divorced']
#
# OverTime:
# ['Yes' 'No']

# %%
df.describe().T
# Out:
#                            count          mean          std     min     25%  \
# Age                       1470.0     36.923810     9.135373    18.0    30.0
# Attrition                 1470.0      0.161224     0.367863     0.0     0.0
# DailyRate                 1470.0    802.485714   403.509100   102.0   465.0
# DistanceFromHome          1470.0      9.192517     8.106864     1.0     2.0
# Education                 1470.0      2.912925     1.024165     1.0     2.0
# EnvironmentSatisfaction   1470.0      2.721769     1.093082     1.0     2.0
# HourlyRate                1470.0     65.891156    20.329428    30.0    48.0
# JobInvolvement            1470.0      2.729932     0.711561     1.0     2.0
# JobLevel                  1470.0      2.063946     1.106940     1.0     1.0
# JobSatisfaction           1470.0      2.728571     1.102846     1.0     2.0
# MonthlyIncome             1470.0   6502.931293  4707.956783  1009.0  2911.0
# ...

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df["YearsAtCompany"].describe()
# Out:
# count    1470.000000
# mean        7.008163
# std         6.126525
# min         0.000000
# 25%         3.000000
# 50%         5.000000
# 75%         9.000000
# max        40.000000
# Name: YearsAtCompany, dtype: float64

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(8, 5))
plt.hist(df["YearsAtCompany"], bins=20)
plt.xlabel("Years at Company")
plt.ylabel("Number of Employees")
plt.title("Distribution of Years at Company")
plt.show()

# %%
df["YearsInCurrentRole"].describe()
# Out:
# count    1470.000000
# mean        4.229252
# std         3.623137
# min         0.000000
# 25%         2.000000
# 50%         3.000000
# 75%         7.000000
# max        18.000000
# Name: YearsInCurrentRole, dtype: float64

# %%
df["YearsSinceLastPromotion"].describe()
# Out:
# count    1470.000000
# mean        2.187755
# std         3.222430
# min         0.000000
# 25%         0.000000
# 50%         1.000000
# 75%         3.000000
# max        15.000000
# Name: YearsSinceLastPromotion, dtype: float64

# %%
df["YearsWithCurrManager"].describe()
# Out:
# count    1470.000000
# mean        4.123129
# std         3.568136
# min         0.000000
# 25%         2.000000
# 50%         3.000000
# 75%         7.000000
# max        17.000000
# Name: YearsWithCurrManager, dtype: float64

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(8, 5))

plt.hist(df["YearsInCurrentRole"], bins=15, alpha=0.5, label="Current Role")
plt.hist(df["YearsSinceLastPromotion"], bins=15, alpha=0.5, label="Since Last Promotion")
plt.hist(df["YearsWithCurrManager"], bins=15, alpha=0.5, label="Current Manager")

plt.xlabel("Years")
plt.ylabel("Number of Employees")
plt.title("Career Progression Variables")
plt.legend()
plt.show()

# %%
df.groupby("JobRole")["YearsSinceLastPromotion"].mean()
# Out:
# JobRole
# Healthcare Representative    2.969466
# Human Resources              1.269231
# Laboratory Technician        1.420849
# Manager                      4.833333
# Manufacturing Director       2.117241
# Research Director            3.187500
# Research Scientist           1.506849
# Sales Executive              2.484663
# Sales Representative         1.060241
# Name: YearsSinceLastPromotion, dtype: float64

# %%
df.groupby("JobLevel")["YearsSinceLastPromotion"].mean()
# Out:
# JobLevel
# 1    1.193370
# 2    1.885768
# 3    3.353211
# 4    4.839623
# 5    4.594203
# Name: YearsSinceLastPromotion, dtype: float64

# %%
plt.figure(figsize=(8, 5))

plt.scatter(
    df["YearsAtCompany"],
    df["YearsSinceLastPromotion"],
    alpha=0.5
)

plt.xlabel("Years at Company")
plt.ylabel("Years Since Last Promotion")
plt.title("Years at Company vs Years Since Last Promotion")

plt.show()

# %%
plt.figure(figsize=(8, 5))

plt.scatter(
    df["YearsInCurrentRole"],
    df["YearsSinceLastPromotion"],
    alpha=0.5
)

plt.xlabel("Years in Current Role")
plt.ylabel("Years Since Last Promotion")
plt.title("Years in Current Role vs Years Since Last Promotion")

plt.show()

# %%
df.groupby("TrainingTimesLastYear")["YearsSinceLastPromotion"].mean()
# Out:
# TrainingTimesLastYear
# 0    2.351852
# 1    2.394366
# 2    2.098720
# 3    2.240326
# 4    2.308943
# 5    1.966387
# 6    2.353846
# Name: YearsSinceLastPromotion, dtype: float64

# %%
df["YearsWithCurrManager"].describe()
# Out:
# count    1470.000000
# mean        4.123129
# std         3.568136
# min         0.000000
# 25%         2.000000
# 50%         3.000000
# 75%         7.000000
# max        17.000000
# Name: YearsWithCurrManager, dtype: float64

# %%
plt.figure(figsize=(8, 5))

plt.scatter(
    df["YearsWithCurrManager"],
    df["YearsSinceLastPromotion"],
    alpha=0.5
)

plt.xlabel("Years With Current Manager")
plt.ylabel("Years Since Last Promotion")
plt.title("Manager Stability vs Promotion Gap")

plt.show()

# %%
df.groupby("JobLevel")["YearsInCurrentRole"].mean()
# Out:
# JobLevel
# 1    2.513812
# 2    4.456929
# 3    6.114679
# 4    6.537736
# 5    6.463768
# Name: YearsInCurrentRole, dtype: float64

# %%
df.groupby("JobSatisfaction")["Attrition"].value_counts(normalize=True)
# Out:
# JobSatisfaction  Attrition
# 1                0            0.771626
#                  1            0.228374
# 2                0            0.835714
#                  1            0.164286
# 3                0            0.834842
#                  1            0.165158
# 4                0            0.886710
#                  1            0.113290
# Name: proportion, dtype: float64

# %%
df.groupby("TrainingTimesLastYear")["YearsSinceLastPromotion"].mean()
# Out:
# TrainingTimesLastYear
# 0    2.351852
# 1    2.394366
# 2    2.098720
# 3    2.240326
# 4    2.308943
# 5    1.966387
# 6    2.353846
# Name: YearsSinceLastPromotion, dtype: float64

# %%
pd.crosstab(
    df["JobSatisfaction"],
    df["Attrition"],
    normalize="index"
)
# Out:
# Attrition               0         1
# JobSatisfaction
# 1                0.771626  0.228374
# 2                0.835714  0.164286
# 3                0.834842  0.165158
# 4                0.886710  0.113290

# %%
pd.crosstab(
    df["OverTime"],
    df["Attrition"],
    normalize="index"
)
# Out:
# Attrition         0         1
# OverTime
# No         0.895636  0.104364
# Yes        0.694712  0.305288

# %%
pd.crosstab(
    df["WorkLifeBalance"],
    df["Attrition"],
    normalize="index"
)
# Out:
# Attrition               0         1
# WorkLifeBalance
# 1                0.687500  0.312500
# 2                0.831395  0.168605
# 3                0.857783  0.142217
# 4                0.823529  0.176471

# %%
pd.crosstab(
    df["JobInvolvement"],
    df["Attrition"],
    normalize="index"
)
# Out:
# Attrition              0         1
# JobInvolvement
# 1               0.662651  0.337349
# 2               0.810667  0.189333
# 3               0.855991  0.144009
# 4               0.909722  0.090278

# %%
df.groupby("Attrition")[
    ["YearsSinceLastPromotion", "YearsInCurrentRole", "YearsAtCompany"]
].mean()
# Out:
#            YearsSinceLastPromotion  YearsInCurrentRole  YearsAtCompany
# Attrition
# 0                         2.234388            4.484185        7.369019
# 1                         1.945148            2.902954        5.130802

# %%
df.groupby("JobLevel")["MonthlyIncome"].mean()
# Out:
# JobLevel
# 1     2786.915285
# 2     5502.277154
# 3     9817.252294
# 4    15503.783019
# 5    19191.826087
# Name: MonthlyIncome, dtype: float64

# %%
df["YearsAtCompany"].eq(0).sum()
# Out:
# np.int64(44)

# %%
import numpy as np
df["PromotionGapRatio"] = np.where(
    df["YearsAtCompany"] == 0,
    0,
    df["YearsSinceLastPromotion"] / df["YearsAtCompany"]
)

# %%
df[["YearsAtCompany", "YearsSinceLastPromotion", "PromotionGapRatio"]].head(10)
# Out:
#    YearsAtCompany  YearsSinceLastPromotion  PromotionGapRatio
# 0               6                        0           0.000000
# 1              10                        1           0.100000
# 2               0                        0           0.000000
# 3               8                        3           0.375000
# 4               2                        2           1.000000
# 5               7                        3           0.428571
# 6               1                        0           0.000000
# 7               1                        0           0.000000
# 8               9                        1           0.111111
# 9               7                        7           1.000000

# %%
df["PromotionGapRatio"].describe()
# Out:
# count    1470.000000
# mean        0.290232
# std         0.340521
# min         0.000000
# 25%         0.000000
# 50%         0.166667
# 75%         0.500000
# max         1.000000
# Name: PromotionGapRatio, dtype: float64
